# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET
from json import JSONDecodeError

# %%
project_filters = {
    "location": "",
    "coordinates": [
        [
            "",
            ""
        ]
    ],
    "range": "2",
    "priceRangeLower": "0",
    "priceRangeUpper": "0",
    "flatType": "",
    "waitingTime": "",
    "modeOfSale": "SBF",
    "floorRange": "",
    "remainingLeaseRangeLower": 1,
    "remainingLeaseRangeUpper": 99,
    "ethnicGroup": "",
    "rank": "Location, Price Range, Flat Type, Remaining Lease",
    "town": ""
}

# %%
def read_header(header_name):
    with open(header_name) as f:
        header_get_projects = {}
        for line in f:
            key_value = line.replace("\n", "").split(":")
            header_get_projects[key_value[0]] = key_value[1]
    return header_get_projects


def get_all_projects_data(header_get_projects, project_filters):
    r = requests.post(
        "https://homes.hdb.gov.sg/home-api/public/v1/map/getCoordinatesByFilters", 
        headers=header_get_projects, json=project_filters)
    try:
        data = r.json()
    except JSONDecodeError:
        print(r.content)
        raise JSONDecodeError
    return data

def get_ethnic_quotas(header_get_projects, project_id):
    r = requests.post(
        "https://homes.hdb.gov.sg/home-api/public/v1/launch/getProjectAvailabilityAndEthnic", 
        headers=header_get_projects, json=project_id)
    try:
        data = r.json()
    except JSONDecodeError:
        print(r.content)
        raise JSONDecodeError
    else:
        data["project_id"] = project_id
    return data


def get_required_project_data(project_data):
    required_data = {} 
    required_data["coordinates"] = project_data["coordinates"]
    properties = project_data["properties"]
    required_data["project"] = properties["address"]
    
    required_data["region"] = properties["region"]
    description = properties["description"][0]
    try:
        description1 = properties["description"][1]
    except IndexError:
        pass
    else:
        print(description1)
    required_data["town"] = description["town"]
    required_data["project_id"] = description["projectId"]        
    return required_data

def get_all_required_projects_data(all_projects_data):
    all_required_projects_data = []
    for project_data in all_projects_data:
        required_project_data = get_required_project_data(project_data)
        all_required_projects_data.append(required_project_data)

    return all_required_projects_data

def get_all_units_xml_in_project(project_id, header_get_projects):
    r = requests.post(
        "https://homes.hdb.gov.sg/home-api/public/v1/launch/getUnitXml", 
        headers=header_get_projects, 
        json={"projectId":project_id})
    unit_xml = ET.fromstring(r.content)
    return unit_xml

def get_project_units(unit_xml):
    units = unit_xml.findall("./standard-project-info/unit-details/unit")
    return units
def get_project_name(unit_xml):
    project_name = unit_xml.find("./project-name").text
    return project_name
def get_project_streetname(unit_xml):
    street_name = unit_xml.find("./standard-project-info/key/street-name").text
    return street_name
def get_remaining_lease(unit_xml):
    remaining_lease = unit_xml.find("./standard-project-info/key/remaining-lease").text
    return remaining_lease
def get_unit_details(unit):
    unit_details = {}
    for unit_detail in unit:
        unit_details[unit_detail.tag] = unit_detail.text
    return unit_details

def get_all_unit_details_in_project(unit_xml, required_project_data):
    project_units = get_project_units(unit_xml)
    street_name = get_project_streetname(unit_xml)
    remaining_lease = get_remaining_lease(unit_xml)
    project_name = get_project_name(unit_xml)
    unit_details_1 = {
        "remaining_lease": remaining_lease, 
        "street_name": street_name,
        "project_name": project_name}
    all_unit_details_for_project = []
    for unit in project_units:
        unit_details_2 = get_unit_details(unit)
        unit_details = {**required_project_data, **unit_details_1, **unit_details_2}
        all_unit_details_for_project.append(unit_details)
    return all_unit_details_for_project

def get_all_unit_details_for_all_projects(all_required_projects_data):
    all_unit_details_for_all_projects = []
    projects_ethnic_quota_data = []
    for i, required_project_data in enumerate(all_required_projects_data):
        print(f"""{i+1} {required_project_data["project"]}""")
        project_id = required_project_data["project_id"]
        all_units_xml = get_all_units_xml_in_project(project_id, header_get_projects)
        all_unit_details_in_project = get_all_unit_details_in_project(all_units_xml, required_project_data)

        project_ethnic_quota_data = get_ethnic_quotas(header_get_projects, project_id)

        all_unit_details_for_all_projects.extend(all_unit_details_in_project)
        projects_ethnic_quota_data.append(project_ethnic_quota_data)
    return all_unit_details_for_all_projects, projects_ethnic_quota_data

# %%
header_get_projects = read_header("header_get_projects")
header_get_projects
# Out:
# {'authority': 'homes.hdb.gov.sg',
#  'accept': 'application/json, text/plain, */*',
#  'content-type': 'application/json',
#  'origin': 'https',
#  'referer': 'https',
#  'sessionid': 'LO165365523118802t874vxAA9XjL2f',
#  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.64 Safari/537.36 Edg/101.0.1210.53'}

# %%
all_projects_data = get_all_projects_data(header_get_projects, project_filters)
all_required_projects_data = get_all_required_projects_data(all_projects_data)
result = get_all_unit_details_for_all_projects(all_required_projects_data)
# Out:
# 1 Sunshine Court
# 2 Sunshine Gardens
# 3 Limbang Green
# 4 Choa Chu Kang Dr
# 5 Keat Hong Verge
# 6 Keat Hong Axis
# 7 Teck Whye Vista
# 8 Teck Whye View
# 9 Teck Whye Heights II
# 10 Choa Chu Kang Ave 3
# 11 Clementi West St 2
# 12 West Coast Rd
# 13 Clementi West St 2
# 14 Sunset Way Residence
# 15 Clementi Northarc
# 16 Clementi Gateway
# 17 Clementi Ave 4
# 18 Clementi Shine
# 19 Clementi Ave 5
# 20 Clementi Ave 5
# 21 Clementi Ave 5
# 22 Trivelis
# 23 Clementi Crest
# 24 Clementi Peaks
# 25 Clementi Heights
# 26 West Coast Vista
# 27 Clementi West St 1
# 28 Waterloo Centre
# 29 Cantonment Towers
# 30 Blangah Garden
# 31 Blangah Court
# 32 Telok Blangah Beacon
# 33 Telok Blangah Towers
# 34 Telok Blangah Parcview
# 35 Lengkok Bahru
# 36 Bukit Purmei Ville
# 37 Jln Bt Merah
# 38 Kim Tian Towers
# 39 Havelock View
# 40 Boon Tiong Arcadia
# 41 Golden Tulip
# 42 City Vue @henderson
# 43 Bishan St 13
# 44 Golden Jasmine
# 45 Bishan Ridges
# 46 Bishan Towers
# 47 Bishan St 12
# 48 Bishan View
# 49 Bishan Green
# 50 Bishan St 24
# 51 Bt Batok West Ave 6
# 52 Bt Batok West Ave 8
# 53 Golden Daisy
# 54 Bt Batok East Ave 4
# 55 Bt Batok St 21
# 56 Goodview Gardens
# 57 Bt Batok St 32
# 58 West Scape @ Bukit Batok
# 59 West Hill @ Bukit Batok
# 60 West Plains @ Bukit Batok
# 61 West Quarry @ Bukit Batok
# 62 West Crest @ Bukit Batok
# 63 West Valley @ Bukit Batok
# 64 West Edge @ Bukit Batok
# 65 Fengshan Greenville
# 66 Fengshan Precinct
# 67 Pearl Garden
# 68 Bedok Nth Rd
# 69 Ping Yi Greens
# 70 Ping-an Gardens
# 71 Bedok South Horizon
# 72 Bedok South Parkview
# 73 New Upp Changi Rd
# 74 Bedok Sth Ave 1
# 75 Bedok Beacon
# 76 Garden Hill
# 77 Golden Oaks
# 78 Bedok Nth St 3
# 79 Bedok North Vale
# 80 Bedok North Green
# 81 Bedok Nth Ave 1
# 82 Eunos Heights
# 83 Eunos Vista
# 84 Eunos Spring
# 85 Eunos Rainbow
# 86 Gangsa Rd
# 87 Fajar Spring
# 88 Senja Gateway
# 89 Senja Heights
# 90 Senja Valley
# 91 Senja Ridges
# 92 Toh Yi Gardens
# 93 Golden Kismis
# 94 Teck Ghee Horizon
# 95 Cheng San View
# 96 Cheng San Court
# 97 Cheng San Crest
# 98 Yio Chu Kang Green
# 99 Yio Chu Kang Beacon
# 100 Amk Central Heights
# 101 Yio Chu Kang Grove
# 102 Kebun Baru Link 2
# 103 The Clover @ Kebun Baru
# 104 Ang Mo Kio Court
# 105 Kebun Baru Edge
# 106 Teck Ghee Vista
# 107 Ang Mo Kio 31
# 108 Macpherson Weave
# 109 Macpherson Garden
# 110 Balam Gardens
# 111 Macpherson View
# 112 Aljunied Cres
# 113 Cassia Cres
# 114 Dakota One
# 115 Dakota Breeze
# 116 Pine Vista
# 117 Kallang Airport 10
# 118 Eunos Court
# 119 Ubi Ave 1
# 120 St George's Towers
# 121 Geylang Bahru Ville
# 122 Mcnair Towers
# 123 Towner Crest
# 124 Mcnair Heights
# 125 Kempas Residences
# 126 Rajah Court
# 127 Whampoa Gardens
# 128 Whampoa Dew
# 129 Di Tanjong Rhu
# 130 Farrer Park View
# 131 Kallang Trivista
# 132 Kallang Residences
# 133 Kallang Breeze
# 134 Kallang Heights
# 135 Hougang Ave 2
# 136 Paya Lebar Lodge
# 137 Hougang St 11
# 138 Hougang Heights
# 139 Buangkok Tropica
# 140 Buangkok Woods
# 141 Buangkok Parkvista
# 142 Buangkok Square
# 143 Hougang St 91
# 144 Hougang Ave 9
# 145 Hougang View
# 146 Hougang Ave 5
# 147 Hougang Dewcourt
# 148 Hougang Rivercourt
# 149 Hougang Meadow
# 150 Hougang Ave 5
# 151 Golden Mint
# 152 Hougang Ave 4
# 153 Hougang Ave 8
# 154 Hougang Ave 8
# 155 Hougang Ave 8
# 156 Jurong East St 21
# 157 Golden Willows
# 158 Hong Kah East Garden
# 159 Teban Place
# 160 Corporation Spring
# 161 Corporation Tiara
# 162 Yung Kuang Court
# 163 Yung Ho Spring II
# 164 Jurong West St 81
# 165 Jurong West St 81
# 166 Jurong West St 81
# 167 Jurong West St 81
# 168 Boon Lay View
# 169 Boon Lay Place
# 170 Nanyang Emerald
# 171 Jurong West Jewel
# 172 Jurong West St 91
# 173 Jurong West St 93
# 174 Jurong West St 42
# 175 Golden Orchid
# 176 Hong Kah Court
# 177 Jurong West St 42
# 178 Jurong West St 52
# 179 Golden Peony
# 180 Jurong West St 52
# 181 Jurong West Ave 1
# 182 Marine Drive Gardens
# 183 Marine Crescent Ville
# 184 Lew Lian Gardens
# 185 Golden Ginger
# 186 Boundary Ville
# 187 Serangoon Green
# 188 Serangoon Ave 3
# 189 Serangoon Ave 2
# 190 Chuan Village
# 191 Serangoon Ave 3
# 192 Serangoon Ave 3
# 193 Eastglen @ Canberra
# 194 Eastdelta @ Canberra
# 195 Canberra Vista
# 196 Sun Sails
# 197 Rivervale Arc
# 198 Rivervale Gateway
# 199 Rivervale Shores
# 200 Compassvale Ancilla
# 201 Compassvale Helm
# 202 Fernvale Rivergrove
# 203 Fernvale Vines
# 204 Fernvale Woods
# 205 Fernvale Glades
# 206 Fernvale Dew
# 207 Fernvale Acres
# 208 Punggol Ctrl
# 209 Edgefield Plains
# 210 Punggol Sapphire
# 211 Punggol Emerald
# 212 Punggol Ripples
# 213 Matilda Sundeck
# 214 Matilda Court
# 215 Waterway Cascadia
# 216 Northshore Straitsview
# 217 Waterfront II @ Northshore
# 218 Punggol Point Crown
# 219 Punggol Point Woods
# 220 Punggol Point Cove
# 221 Waterfront I @ Northshore
# 222 Northshore Residences II
# 223 Northshore Residences I
# 224 Northshore Edge
# 225 Punggol Spectra
# 226 Waterway Sunray
# 227 Waterway Sundew
# 228 Waterway Brooks
# 229 Waterway Banks
# 230 Waterway Sunrise I
# 231 Pasir Ris Dr 6
# 232 Costa Ris
# 233 Costa Grove
# 234 Pasir Ris One
# 235 Elias View
# 236 Pasir Ris St 71
# 237 Pasir Ris St 12
# 238 Pasir Ris St 11
# 239 Pasir Ris St 11
# 240 Pasir Ris St 11
# 241 Pasir Ris St 21
# 242 Pasir Ris St 21
# 243 Dover Gardens
# 244 Skyresidence @ Dawson
# 245 Skyterrace @ Dawson
# 246 Skyoasis @ Dawson
# 247 Skyparc @ Dawson
# 248 Strathmore Green
# 249 Stirling View
# 250 Commonwealth View
# 251 Holland Ave
# 252 Ghim Moh Green
# 253 Ghim Moh Gardens
# 254 Ghim Moh Edge
# 255 Ghim Moh Valley
# 256 Woodlands Glade
# 257 Woodlands Cres
# 258 Woodlands Spring
# 259 Admiralty Vista
# 260 Marsiling Greenview
# 261 Marsiling Spring
# 262 Marsiling Heights
# 263 Woodlands St 13
# 264 Marsiling Rd
# 265 Treegrove@woodlands
# 266 Woodlands St 81
# 267 Woodlands St 83
# 268 Marsiling Sapphire
# 269 Marsiling Admiralty Park
# 270 Urbanville @ Woodlands
# 271 Woodgrove Ascent
# 272 Woodlands St 41
# 273 Champions Court
# 274 Champions Bliss
# 275 Champions Green
# 276 Admiralty Grove
# 277 Woodlands Ring Rd
# 278 Woodlands Dr 52
# 279 Plantation Grange
# 280 Plantation Grove
# 281 Plantation Village
# 282 Plantation Acres
# 283 Garden Vale @ Tengah
# 284 Garden Vines @ Tengah
# 285 Garden Bloom @ Tengah
# 286 Garden Terrace @ Tengah
# 287 Garden Court @ Tengah
# 288 Parc Woods @ Tengah
# 289 Parc Residences @ Tengah
# 290 Tampines Greenleaf
# 291 Tampines Greenvines
# 292 Tampines Greendew
# 293 Tampines Greencourt
# 294 Tampines Greenverge
# 295 Tampines Greenfoliage
# 296 Tampines Greenweave
# 297 Tampines Greenglade
# 298 Tampines Greenglen
# 299 Tampines Greencrest
# 300 Tampines Spring
# 301 Tampines Greenwood
# 302 Tampines Greenspring
# 303 Tampines Greenflora
# 304 Tampines Greenbloom
# 305 Golden Pines
# 306 Tampines Greenopal
# 307 Tampines Greengem
# 308 Tampines Greenemerald
# 309 Simei St 1
# 310 Golden Carnation
# 311 Tampines East Zone 4
# 312 Tampines St 22
# 313 Tampines St 22
# 314 Tampines St 33
# 315 Tampines St 33
# 316 Toa Payoh Eight
# 317 Golden Lotus
# 318 Alkaff Lakeview
# 319 Woodleigh Hillside
# 320 Parkview @ Bidadari
# 321 Alkaff Breeze
# 322 Bartley Greenrise
# 323 Bartley Beacon
# 324 Parkedge @ Bidadari
# 325 Alkaff Courtview
# 326 Alkaff Oasis
# 327 Woodleigh Glen
# 328 Toa Payoh Central
# 329 Central Horizon
# 330 Toa Payoh Crest
# 331 Toa Payoh Ridge
# 332 Toa Payoh Green
# 333 Lor 8 Toa Payoh
# 334 Lor 8 Toa Payoh
# 335 Kim Keat Beacon
# 336 Kim Keat Ripples
# 337 Golden Palms
# 338 Yishun Ave 3
# 339 Nee Soon Central Spring
# 340 Nee Soon Central Vista
# 341 Chong Pang Vale
# 342 Yishun Riverwalk
# 343 Yishun Greenwalk
# 344 Yishun Glen
# 345 Yishun Rivergreen
# 346 Forest Spring @ Yishun
# 347 Melody Spring @ Yishun
# 348 Blossom Spring @ Yishun
# 349 Casa Spring @ Yishun
# 350 Meadow Spring @ Yishun
# 351 Yishun Ave 6
# 352 Yishun Ave 11
# 353 Floral Spring @ Yishun
# 354 Dew Spring @ Yishun
# 355 Acacia Breeze @ Yishun
# 356 Angsana Breeze @ Yishun
# 357 Oleander Breeze @ Yishun
# 358 Yishun Ring Rd
# 359 Fern Grove @ Yishun

# %%
flat_data = result[0]
ethnic_quota_data = result[1]

# %%
flat_data_df = pd.DataFrame.from_dict(flat_data)
flat_data_df.to_csv("unit_details.csv", index=False)

# %%
flat_data_df
# Out:
#                                    coordinates                   project  \
# 0     [1.3766745369726854, 103.73789561376547]            Sunshine Court
# 1     [1.3766745369726854, 103.73789561376547]            Sunshine Court
# 2     [1.3765873889910192, 103.74007753792313]          Sunshine Gardens
# 3     [1.3765873889910192, 103.74007753792313]          Sunshine Gardens
# 4     [1.3942738802398278, 103.74452794822368]             Limbang Green
# ...                                        ...                       ...
# 1947   [1.418883880805233, 103.84487594211994]    Acacia Breeze @ Yishun
# 1948   [1.413868249473606, 103.84013548258679]   Angsana Breeze @ Yishun
# 1949  [1.4156731558147704, 103.84143663027895]  Oleander Breeze @ Yishun
# 1950  [1.4193039750769822, 103.83535078902591]            Yishun Ring Rd
# 1951   [1.4210486875965123, 103.8421792642465]       Fern Grove @ Yishun
#
#             region           town  \
# 0      WEST REGION  Choa Chu Kang
# 1      WEST REGION  Choa Chu Kang
# 2      WEST REGION  Choa Chu Kang
# 3      WEST REGION  Choa Chu Kang
# 4      WEST REGION  Choa Chu Kang
# ...            ...            ...
# 1947  NORTH REGION         Yishun
# 1948  NORTH REGION         Yishun
# 1949  NORTH REGION         Yishun
# 1950  NORTH REGION         Yishun
# 1951  NORTH REGION         Yishun
#
#                                        project_id remaining_lease  \
# 0     2022-05_SBF_Q0NLX040QzE0XzE2NTAzNDk4MDAwNTM   15 - 45 years
# 1     2022-05_SBF_Q0NLX040QzE0XzE2NTAzNDk4MDAwNTM   15 - 45 years
# 2     2022-05_SBF_Q0NLX040QzE1XzE2NTMzNzM4MDAwNDA        94 years
# 3     2022-05_SBF_Q0NLX040QzE1XzE2NTMzNzM4MDAwNDA        94 years
# 4     2022-05_SBF_Q0NLX041QzEyXzE2NTAzNDYyMDAwODg   15 - 45 years
# ...                                           ...             ...
# 1947     2022-05_SBF_WVNfTjVDMl8xNjUwMzQ2MjAwMDgy        93 years
# 1948     2022-05_SBF_WVNfTjVDNF8xNjUwMzUzNDAwMDM1        95 years
# 1949     2022-05_SBF_WVNfTjVDNl8xNjUwMzQyNjAwMDI3        95 years
# 1950     2022-05_SBF_WVNfTjZDMl8xNjUwMzM5MDAwMTYy        65 years
# 1951   2022-05_SBF_WVNfTjZDMTdfMTY1MDM0MjYwMDEyMw        96 years
#
#               street_name              project_name  \
# 0     Choa Chu Kang Ave 5            Sunshine Court
# 1     Choa Chu Kang Ave 5            Sunshine Court
# 2     Choa Chu Kang Ave 5          Sunshine Gardens
# 3     Choa Chu Kang Ave 5          Sunshine Gardens
# 4     Choa Chu Kang St 52             Limbang Green
# ...                   ...                       ...
# 1947         Yishun St 51    Acacia Breeze @ Yishun
# 1948         Yishun Ave 4   Angsana Breeze @ Yishun
# 1949         Yishun St 51  Oleander Breeze @ Yishun
# 1950       Yishun Ring Rd            Yishun Ring Rd
# 1951         Yishun Ave 4       Fern Grove @ Yishun
#
#                            flat-type block-number                  unit-id  \
# 0                       2-Room Flexi         476A   2022-05_SBF_476A_02_01
# 1                       2-Room Flexi         476A   2022-05_SBF_476A_09_07
# 2                             5-Room         488C  2022-05_SBF_488C_02_161
# 3                             5-Room         488C  2022-05_SBF_488C_02_163
# 4                       2-Room Flexi          570   2022-05_SBF_570_02_224
# ...                              ...          ...                      ...
# 1947  3-Room (Income Ceiling $7,000)         505A   2022-05_SBF_505A_07_10
# 1948                          4-Room         509B   2022-05_SBF_509B_03_20
# 1949                          4-Room         511A  2022-05_SBF_511A_03_409
# 1950  3-Room (Income Ceiling $7,000)          617  2022-05_SBF_617_02_3248
# 1951                          5-Room         673C  2022-05_SBF_673C_08_688
#
#      unit-number level area deliveryPossessionDate estimatedCompletionDate  \
# 0             01    02   36         Keys Available                       -
# 1             07    09   47         Keys Available                       -
# 2            161    02  113         Keys Available                       -
# 3            163    02  113         Keys Available                       -
# 4            224    02   47         Keys Available                       -
# ...          ...   ...  ...                    ...                     ...
# 1947          10    07   68         Keys Available                       -
# 1948          20    03   93         Keys Available                       -
# 1949         409    03   93         Keys Available                       -
# 1950        3248    02   73         Keys Available                       -
# 1951         688    08  112         Keys Available                       -
#
#        price  short-lease-price  \
# 0      57200                NaN
# 1      84400                NaN
# 2     405000                NaN
# 3     405000                NaN
# 4      88500                NaN
# ...      ...                ...
# 1947  253000                NaN
# 1948  338000                NaN
# 1949  353000                NaN
# 1950  213000                NaN
# 1951  469000                NaN
#
#                                           price-tooltip  \
# 0     <![CDATA[<br>$57,200 - 45 Years <br>$55,000 - ...
# 1     <![CDATA[<br>$84,400 - 45 Years <br>$80,900 - ...
# 2                                                   NaN
# 3                                                   NaN
# 4     <![CDATA[<br>$88,500 - 45 Years <br>$84,800 - ...
# ...                                                 ...
# 1947                                                NaN
# 1948                                                NaN
# 1949                                                NaN
# 1950                                                NaN
# 1951                                                NaN
#
#                                     re-purchase-tooltip
# 0     You may view floor plans and photographs (if a...
# 1     You may view floor plans and photographs (if a...
# 2                                                   NaN
# 3                                                   NaN
# 4     You may view floor plans and photographs (if a...
# ...                                                 ...
# 1947  You may view floor plans and photographs (if a...
# 1948  You may view floor plans and photographs (if a...
# 1949  You may view floor plans and photographs (if a...
# 1950  You may view floor plans and photographs (if a...
# 1951  You may view floor plans and photographs (if a...
#
# [1952 rows x 20 columns]

# %%
def process_ethnic_data(ethnic_quota):
    processed_datas = []
    for key, value in ethnic_quota.items():
        if key == "projectBlockFlatTypeInfoMap":     
            block = ethnic_quota["projectBlockFlatTypeInfoMap"]
            for blk1, flat_type1 in block.items():
                processed_data = {}
                processed_data["project_id"] =  ethnic_quota["project_id"]
                for flat_type2, blk2 in flat_type1.items():
                    processed_data["block"] = blk2["block"]
                    processed_data["chinese"] = blk2["chinese"]
                    processed_data["malay"] = blk2["malay"]
                    processed_data["indian"] = blk2["indian"]
                processed_datas.append(processed_data)
    return processed_datas
l = list(map(process_ethnic_data, ethnic_quota_data))
import itertools
flattened_l = list(itertools.chain(*l))

# %%
ethnic_quota_df = pd.DataFrame(flattened_l).rename(columns={"block": "block-number"})
ethnic_quota_df
# Out:
#                                       project_id block-number  chinese  malay  \
# 0    2022-05_SBF_Q0NLX040QzE0XzE2NTAzNDk4MDAwNTM         476A        2      2
# 1    2022-05_SBF_Q0NLX040QzE1XzE2NTMzNzM4MDAwNDA         488C        2      2
# 2    2022-05_SBF_Q0NLX041QzEyXzE2NTAzNDYyMDAwODg          573        2      2
# 3    2022-05_SBF_Q0NLX041QzEyXzE2NTAzNDYyMDAwODg          570        1      1
# 4    2022-05_SBF_Q0NLX041QzEyXzE2NTAzNDYyMDAwODg          571        1      1
# ..                                           ...          ...      ...    ...
# 778     2022-05_SBF_WVNfTjVDMl8xNjUwMzQ2MjAwMDgy         505A        1      1
# 779     2022-05_SBF_WVNfTjVDNF8xNjUwMzUzNDAwMDM1         509B        1      1
# 780     2022-05_SBF_WVNfTjVDNl8xNjUwMzQyNjAwMDI3         511A        1      1
# 781     2022-05_SBF_WVNfTjZDMl8xNjUwMzM5MDAwMTYy          617        1      1
# 782   2022-05_SBF_WVNfTjZDMTdfMTY1MDM0MjYwMDEyMw         673C        1      0
#
#      indian
# 0         2
# 1         1
# 2         2
# 3         1
# 4         1
# ..      ...
# 778       1
# 779       1
# 780       1
# 781       1
# 782       1
#
# [783 rows x 5 columns]

# %%
flat_data_df_final = flat_data_df.merge(ethnic_quota_df, how="left", on=["project_id", "block-number"])
flat_data_df_final = flat_data_df_final.drop(columns=["price-tooltip", "re-purchase-tooltip"])

flat_data_df_final["level"] = pd.to_numeric(flat_data_df_final["level"])
flat_data_df_final["keys_available"] = flat_data_df_final["deliveryPossessionDate"] == "Keys Available"
flat_data_df_final["estimatedCompletionDate"] = pd.to_datetime(flat_data_df_final["estimatedCompletionDate"], errors="coerce")
flat_data_df_final["deliveryPossessionDate"] = pd.to_datetime(flat_data_df_final["deliveryPossessionDate"], errors="coerce")
flat_data_df_final.to_csv("may_sbf_2022_final.csv", index=False)

# %%
flat_data_df_final
# Out:
#                                    coordinates                   project  \
# 0     [1.3766745369726854, 103.73789561376547]            Sunshine Court
# 1     [1.3766745369726854, 103.73789561376547]            Sunshine Court
# 2     [1.3765873889910192, 103.74007753792313]          Sunshine Gardens
# 3     [1.3765873889910192, 103.74007753792313]          Sunshine Gardens
# 4     [1.3942738802398278, 103.74452794822368]             Limbang Green
# ...                                        ...                       ...
# 1947   [1.418883880805233, 103.84487594211994]    Acacia Breeze @ Yishun
# 1948   [1.413868249473606, 103.84013548258679]   Angsana Breeze @ Yishun
# 1949  [1.4156731558147704, 103.84143663027895]  Oleander Breeze @ Yishun
# 1950  [1.4193039750769822, 103.83535078902591]            Yishun Ring Rd
# 1951   [1.4210486875965123, 103.8421792642465]       Fern Grove @ Yishun
#
#             region           town  \
# 0      WEST REGION  Choa Chu Kang
# 1      WEST REGION  Choa Chu Kang
# 2      WEST REGION  Choa Chu Kang
# 3      WEST REGION  Choa Chu Kang
# 4      WEST REGION  Choa Chu Kang
# ...            ...            ...
# 1947  NORTH REGION         Yishun
# 1948  NORTH REGION         Yishun
# 1949  NORTH REGION         Yishun
# 1950  NORTH REGION         Yishun
# 1951  NORTH REGION         Yishun
#
#                                        project_id remaining_lease  \
# 0     2022-05_SBF_Q0NLX040QzE0XzE2NTAzNDk4MDAwNTM   15 - 45 years
# 1     2022-05_SBF_Q0NLX040QzE0XzE2NTAzNDk4MDAwNTM   15 - 45 years
# 2     2022-05_SBF_Q0NLX040QzE1XzE2NTMzNzM4MDAwNDA        94 years
# 3     2022-05_SBF_Q0NLX040QzE1XzE2NTMzNzM4MDAwNDA        94 years
# 4     2022-05_SBF_Q0NLX041QzEyXzE2NTAzNDYyMDAwODg   15 - 45 years
# ...                                           ...             ...
# 1947     2022-05_SBF_WVNfTjVDMl8xNjUwMzQ2MjAwMDgy        93 years
# 1948     2022-05_SBF_WVNfTjVDNF8xNjUwMzUzNDAwMDM1        95 years
# 1949     2022-05_SBF_WVNfTjVDNl8xNjUwMzQyNjAwMDI3        95 years
# 1950     2022-05_SBF_WVNfTjZDMl8xNjUwMzM5MDAwMTYy        65 years
# 1951   2022-05_SBF_WVNfTjZDMTdfMTY1MDM0MjYwMDEyMw        96 years
#
#               street_name              project_name  \
# 0     Choa Chu Kang Ave 5            Sunshine Court
# 1     Choa Chu Kang Ave 5            Sunshine Court
# 2     Choa Chu Kang Ave 5          Sunshine Gardens
# 3     Choa Chu Kang Ave 5          Sunshine Gardens
# 4     Choa Chu Kang St 52             Limbang Green
# ...                   ...                       ...
# 1947         Yishun St 51    Acacia Breeze @ Yishun
# 1948         Yishun Ave 4   Angsana Breeze @ Yishun
# 1949         Yishun St 51  Oleander Breeze @ Yishun
# 1950       Yishun Ring Rd            Yishun Ring Rd
# 1951         Yishun Ave 4       Fern Grove @ Yishun
#
#                            flat-type block-number  ... level area  \
# 0                       2-Room Flexi         476A  ...     2   36
# 1                       2-Room Flexi         476A  ...     9   47
# 2                             5-Room         488C  ...     2  113
# 3                             5-Room         488C  ...     2  113
# 4                       2-Room Flexi          570  ...     2   47
# ...                              ...          ...  ...   ...  ...
# 1947  3-Room (Income Ceiling $7,000)         505A  ...     7   68
# 1948                          4-Room         509B  ...     3   93
# 1949                          4-Room         511A  ...     3   93
# 1950  3-Room (Income Ceiling $7,000)          617  ...     2   73
# 1951                          5-Room         673C  ...     8  112
#
#       deliveryPossessionDate estimatedCompletionDate   price  \
# 0                        NaT                     NaT   57200
# 1                        NaT                     NaT   84400
# 2                        NaT                     NaT  405000
# 3                        NaT                     NaT  405000
# 4                        NaT                     NaT   88500
# ...                      ...                     ...     ...
# 1947                     NaT                     NaT  253000
# 1948                     NaT                     NaT  338000
# 1949                     NaT                     NaT  353000
# 1950                     NaT                     NaT  213000
# 1951                     NaT                     NaT  469000
#
#      short-lease-price chinese  malay  indian  keys_available
# 0                  NaN       2      2       2            True
# 1                  NaN       2      2       2            True
# 2                  NaN       2      2       1            True
# 3                  NaN       2      2       1            True
# 4                  NaN       1      1       1            True
# ...                ...     ...    ...     ...             ...
# 1947               NaN       1      1       1            True
# 1948               NaN       1      1       1            True
# 1949               NaN       1      1       1            True
# 1950               NaN       1      1       1            True
# 1951               NaN       1      0       1            True
#
# [1952 rows x 22 columns]

# %% [markdown]
# # Scraping Application Rates

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
application_rate_url = "https://services2.hdb.gov.sg/webapp/BP13BTOENQWeb/AR_May2022_SBF?strSystem=SBF"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
r = requests.get(application_rate_url, headers=headers)
html = r.content
soup = BeautifulSoup(html)

# %%
application_rate_table = soup.find_all("tbody")[-1]

# %%
fields = ("project", "flat_type", "n_units", "n_applicants", "first_timers", "second_timers", "overall")
application_rate_table_data = application_rate_table.find_all("tr") 
application_rates = []
for row in application_rate_table_data:
    data = [d.text for d in row.find_all("td")]
    if len(data) == 7:
        project = data.pop(0)
    if len(data) < 6:
        continue
    flat_type_application_rate = {"project": project}
    for key, value in zip(fields[1:], data):
        flat_type_application_rate[key] = value
    application_rates.append(flat_type_application_rate)
del application_rates[-1]

# %%
# creating application rates df

application_rates_df = pd.DataFrame(application_rates)
application_rates_df.loc[application_rates_df["flat_type"].str.contains("3-room"), "flat_type"] = "3-room"
# application_rates_df[application_rates_df["flat_type"].str.contains("3-room")]
application_rates_df["flat_type"] = application_rates_df["flat_type"].str.split(" / ")
application_rates_df = application_rates_df.explode("flat_type")
application_rates_df["weight*data"] = pd.to_numeric(application_rates_df["n_units"]) * pd.to_numeric(application_rates_df["overall"])
sums_df = application_rates_df.groupby(["project", "flat_type"]).sum().reset_index()
application_rates_df = application_rates_df.merge(sums_df, on=["project", "flat_type"], how="left")
application_rates_df["application_rate"] = application_rates_df["weight*data_x"] / application_rates_df["weight*data_y"] * pd.to_numeric(application_rates_df["first_timers"])
application_rates_df = application_rates_df.groupby(["project", "flat_type"]).sum().reset_index()
application_rates_df = application_rates_df.drop(columns=["weight*data_x", "weight*data_y"])
application_rates_df = application_rates_df.rename(columns={"project": "town"})
application_rates_df.loc[application_rates_df["town"].str.contains("Jurong"), "town"] = application_rates_df[application_rates_df["town"].str.contains("Jurong")]["town"].str.split(" / ")
application_rates_df = application_rates_df.explode("town")
application_rates_df.loc[application_rates_df["town"] == "West", "town"] = "Jurong West"
application_rates_df["town"] = application_rates_df["town"].str.replace(" / ", "/")

# %%
application_rates_df.to_csv("application_rates.csv")
